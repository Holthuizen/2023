# %%
# !pip install regex
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import math

# %%
#times = np.array([7,15,30]) #time available
#distances = np.array([9,40,200]) #record distances
times = np.array([58,99,64,69]) #time available
distances = np.array([478,2232, 1019, 1071]) #record distances
"""Your toy boat has a starting speed of zero millimeters per millisecond. 
For each whole millisecond you spend at the beginning of the race holding down the button, the boat's speed increases by one millimeter per millisecond."""

#for each pair find the number of ways to beat the record.
answer = 1
for i in range(len(times)): #for all races
    winning_strats = 0
    for b in range(times[i]):
        dist =  b * (times[i] - b)
        print(times[i], distances[i], b, dist)
        if dist > distances[i]:
            winning_strats += 1
    answer *= winning_strats

answer
# Out:
# 58 478 0 0
# 58 478 1 57
# 58 478 2 112
# 58 478 3 165
# 58 478 4 216
# 58 478 5 265
# 58 478 6 312
# 58 478 7 357
# 58 478 8 400
# 58 478 9 441
# 58 478 10 480
# 58 478 11 517
# 58 478 12 552
# 58 478 13 585
# 58 478 14 616
# 58 478 15 645
# 58 478 16 672
# 58 478 17 697
# 58 478 18 720
# 58 478 19 741
# 58 478 20 760
# 58 478 21 777
# 58 478 22 792
# 58 478 23 805
# 58 478 24 816
# 58 478 25 825
# 58 478 26 832
# 58 478 27 837
# 58 478 28 840
# 58 478 29 841
# 58 478 30 840
# 58 478 31 837
# 58 478 32 832
# 58 478 33 825
# 58 478 34 816
# 58 478 35 805
# 58 478 36 792
# 58 478 37 777
# 58 478 38 760
# 58 478 39 741
# 58 478 40 720
# 58 478 41 697
# 58 478 42 672
# 58 478 43 645
# 58 478 44 616
# 58 478 45 585
# 58 478 46 552
# 58 478 47 517
# 58 478 48 480
# 58 478 49 441
# 58 478 50 400
# 58 478 51 357
# 58 478 52 312
# 58 478 53 265
# 58 478 54 216
# 58 478 55 165
# 58 478 56 112
# 58 478 57 57
# 99 2232 0 0
# 99 2232 1 98
# 99 2232 2 194
# 99 2232 3 288
# 99 2232 4 380
# ...

# %%
time = 71530 #time available
#time = 58996469 #puzzel input
distance = 940200 #record distances
#distance = 478223210191071 #puzel input

"""Your toy boat has a starting speed of zero millimeters per millisecond. 
For each whole millisecond you spend at the beginning of the race holding down the button, the boat's speed increases by one millimeter per millisecond."""

#for each pair find the number of ways to beat the record.
answer = 1
winning_strats = 0
for b in range(time):
    dist =  b * (time - b)
    
    if dist > distance:
        
        winning_strats += 1
        #print(dist, winning_strats)

winning_strats
# Out:
# 71503

# %%
time = 71530 #time available
time = 58996469 #puzzel input
distance = 940200 #record distances
distance = 478223210191071 #puzzel input

#abc 
#distance = x*(t-x)
#d = -xˆ2 + xt
# 0 = -xˆ2 + xt - d
a = -1
b = time 
c =  -distance
discriminant = (b**2) - (4*a*c) #5393476195232245
if discriminant > 0:
    x1 = (-b - math.sqrt(discriminant)) / (2*a)
    x2 = (-b + math.sqrt(discriminant)) / (2*a)
    #print(math.ceil(x1), math.ceil(round(x2)) #the correct answer should be around 14, 71516
    #-13 71544 ?

answer = round(abs(math.ceil(x1) - math.ceil(round(x2))))

answer
# Out:
# 39594072
